# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
rev_data = pd.read_csv("Revenue_Data.csv")

# %%
rev_data
# Out:
#           DATE  MRTSSM4453USN
# 0   2019-01-01           4134
# 1   2019-02-01           4116
# 2   2019-03-01           4673
# 3   2019-04-01           4580
# 4   2019-05-01           5109
# 5   2019-06-01           5011
# 6   2019-07-01           5245
# 7   2019-08-01           5270
# 8   2019-09-01           4680
# 9   2019-10-01           4913
# 10  2019-11-01           5312
# 11  2019-12-01           6630
# 12  2020-01-01           4388
# 13  2020-02-01           4533
# 14  2020-03-01           5521
# 15  2020-04-01           5211
# 16  2020-05-01           6263
# 17  2020-06-01           6078
# 18  2020-07-01           6423
# 19  2020-08-01           6099
# 20  2020-09-01           5855
# 21  2020-10-01           6050
# 22  2020-11-01           6088

# %%
rev_data = rev_data.rename(columns= {"MRTSSM4453USN":"Revenue by Million"})
rev_data
# Out:
#           DATE  Revenue by Million
# 0   2019-01-01                4134
# 1   2019-02-01                4116
# 2   2019-03-01                4673
# 3   2019-04-01                4580
# 4   2019-05-01                5109
# 5   2019-06-01                5011
# 6   2019-07-01                5245
# 7   2019-08-01                5270
# 8   2019-09-01                4680
# 9   2019-10-01                4913
# 10  2019-11-01                5312
# 11  2019-12-01                6630
# 12  2020-01-01                4388
# 13  2020-02-01                4533
# 14  2020-03-01                5521
# 15  2020-04-01                5211
# 16  2020-05-01                6263
# 17  2020-06-01                6078
# 18  2020-07-01                6423
# 19  2020-08-01                6099
# 20  2020-09-01                5855
# 21  2020-10-01                6050
# 22  2020-11-01                6088

# %%
plt.bar(rev_data['DATE'], rev_data['Revenue by Million'], width=0.8)
plt.ylabel('Revenue by Million')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
#Need to fix figure size
