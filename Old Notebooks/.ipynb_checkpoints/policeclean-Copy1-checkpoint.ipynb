# %%
# %matplotlib notebook

# %%
#get data from police csv
#import dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
#link to the csv
police_data = pd.read_csv("../Resources/Police_csv.csv")
police_data.head()
# Out:
#       Unnamed: 0 Unsafespeedcrashes/2020 Improperturningcrashes/2020  \
# 0  Entire Period                  19,029                      10,292
# 1         2/3/20                     521                         171
# 2        2/10/20                     535                         193
# 3        2/17/20                     563                         184
# 4        2/24/20                     624                         186
#
#   DUIcrashes/2020 Othercrashes/2020 Unsafespeedcrashes/2019  \
# 0           4,942            10,947                  33,072
# 1             102               253                     708
# 2             120               303                     713
# 3             100               250                     548
# 4              98               292                     674
#
#   Improperturningcrashes/2019 DUIcrashes/2019 Othercrashes/2019
# 0                      10,906           5,589            15,132
# 1                         215             114               277
# 2                         214              82               260
# 3                         169              88               258
# 4                         220             105               272

# %%
#Rename first column to date and remove Entire Period row
police_data.dtypes
# Out:
# Unnamed: 0                     object
# Unsafespeedcrashes/2020        object
# Improperturningcrashes/2020    object
# DUIcrashes/2020                object
# Othercrashes/2020              object
# Unsafespeedcrashes/2019        object
# Improperturningcrashes/2019    object
# DUIcrashes/2019                object
# Othercrashes/2019              object
# dtype: object

# %%
police_data = police_data.rename(columns= {"Unnamed: 0":"Date", "DUIcrashes/2020":"DUI crashes 2020", "DUIcrashes/2019":"DUI crashes 2019"})
police_data.head(20)
# Out:
#              Date Unsafespeedcrashes/2020 Improperturningcrashes/2020  \
# 0   Entire Period                  19,029                      10,292
# 1          2/3/20                     521                         171
# 2         2/10/20                     535                         193
# 3         2/17/20                     563                         184
# 4         2/24/20                     624                         186
# 5          3/2/20                     531                         223
# 6          3/9/20                     655                         269
# 7       3/16/2020                     333                         178
# 8         3/23/20                     161                         150
# 9         3/30/20                     162                         152
# 10         4/6/20                     360                         189
# 11        4/13/20                     156                         115
# 12        4/20/20                     165                         167
# 13        4/27/20                     181                         192
# 14         5/4/20                     207                         185
# 15        5/11/20                     252                         159
# 16        5/18/20                     276                         185
# 17        5/25/20                     241                         167
# 18         6/1/20                     279                         191
# 19         6/8/20                     344                         208
#
#    DUI crashes 2020 Othercrashes/2020 Unsafespeedcrashes/2019  \
# 0             4,942            10,947                  33,072
# 1               102               253                     708
# 2               120               303                     713
# 3               100               250                     548
# 4                98               292                     674
# 5               110               303                     617
# 6               102               253                     593
# 7                58               146                     665
# 8                71               120                     594
# 9                64               116                     562
# 10               66               111                     590
# 11               77               130                     583
# 12               85               146                     605
# 13               61               171                     619
# 14              101               180                     575
# 15               81               185                     738
# 16               85               191                     599
# 17               93               203                     506
# 18              105               192                     630
# 19               99               216                     682
#
#    Improperturningcrashes/2019 DUI crashes 2019 Othercrashes/2019
# 0                       10,906            5,589            15,132
# 1                          215              114               277
# 2                          214               82               260
# 3                          169               88               258
# 4                          220              105               272
# 5                          192               98               263
# 6                          213              124               330
# 7                          193              101               300
# 8                          197               98               279
# 9                          205               96               253
# 10                         193               95               279
# 11                         200               95               278
# 12                         188               92               309
# 13                         236              108               269
# 14                         184               94               278
# 15                         253              116               263
# 16                         194              104               272
# 17                         204              107               285
# 18                         230              109               279
# 19                         209              104               292

# %%
#Remove asterisk from date '3/16/2020'
police_data['Date'].unique()
# Out:
# array(['Entire Period', '2/3/20', '2/10/20', '2/17/20', '2/24/20',
#        '3/2/20', '3/9/20', '3/16/2020', '3/23/20', '3/30/20', '4/6/20',
#        '4/13/20', '4/20/20', '4/27/20', '5/4/20', '5/11/20', '5/18/20',
#        '5/25/20', '6/1/20', '6/8/20', '6/15/20', '6/22/20', '6/29/20',
#        '7/6/20', '7/13/20', '7/20/20', '7/27/20', '8/3/20', '8/10/20',
#        '8/17/20', '8/24/20', '8/31/20', '9/7/20', '9/14/20', '9/21/20',
#        '9/28/20', '10/5/20', '10/12/20', '10/19/20', '10/26/20',
#        '11/2/20', '11/9/20', '11/16/20', '11/23/20', '11/30/20',
#        '12/7/20', '12/14/20', '12/21/20', '12/28/20', '1/4/21', '1/11/21',
#        '1/18/21', '1/25/21', '2/1/21'], dtype=object)

# %%
#Remove first summary row from the data set 'Entire Period'
police_data = police_data.loc[police_data['Date'] !="Entire Period"]
police_data.head(20)
# Out:
#          Date Unsafespeedcrashes/2020 Improperturningcrashes/2020  \
# 1      2/3/20                     521                         171
# 2     2/10/20                     535                         193
# 3     2/17/20                     563                         184
# 4     2/24/20                     624                         186
# 5      3/2/20                     531                         223
# 6      3/9/20                     655                         269
# 7   3/16/2020                     333                         178
# 8     3/23/20                     161                         150
# 9     3/30/20                     162                         152
# 10     4/6/20                     360                         189
# 11    4/13/20                     156                         115
# 12    4/20/20                     165                         167
# 13    4/27/20                     181                         192
# 14     5/4/20                     207                         185
# 15    5/11/20                     252                         159
# 16    5/18/20                     276                         185
# 17    5/25/20                     241                         167
# 18     6/1/20                     279                         191
# 19     6/8/20                     344                         208
# 20    6/15/20                     354                         236
#
#    DUI crashes 2020 Othercrashes/2020 Unsafespeedcrashes/2019  \
# 1               102               253                     708
# 2               120               303                     713
# 3               100               250                     548
# 4                98               292                     674
# 5               110               303                     617
# 6               102               253                     593
# 7                58               146                     665
# 8                71               120                     594
# 9                64               116                     562
# 10               66               111                     590
# 11               77               130                     583
# 12               85               146                     605
# 13               61               171                     619
# 14              101               180                     575
# 15               81               185                     738
# 16               85               191                     599
# 17               93               203                     506
# 18              105               192                     630
# 19               99               216                     682
# 20              101               236                     591
#
#    Improperturningcrashes/2019 DUI crashes 2019 Othercrashes/2019
# 1                          215              114               277
# 2                          214               82               260
# 3                          169               88               258
# 4                          220              105               272
# 5                          192               98               263
# 6                          213              124               330
# 7                          193              101               300
# 8                          197               98               279
# 9                          205               96               253
# 10                         193               95               279
# 11                         200               95               278
# 12                         188               92               309
# 13                         236              108               269
# 14                         184               94               278
# 15                         253              116               263
# 16                         194              104               272
# 17                         204              107               285
# 18                         230              109               279
# 19                         209              104               292
# 20                         221              109               272

# %%
#groupby function to set apart my more important variables
DUI_crashes_df = police_data[["Date", "DUI crashes 2020", "DUI crashes 2019"]].copy()
DUI_crashes_df
# Out:
#          Date DUI crashes 2020 DUI crashes 2019
# 1      2/3/20              102              114
# 2     2/10/20              120               82
# 3     2/17/20              100               88
# 4     2/24/20               98              105
# 5      3/2/20              110               98
# 6      3/9/20              102              124
# 7   3/16/2020               58              101
# 8     3/23/20               71               98
# 9     3/30/20               64               96
# 10     4/6/20               66               95
# 11    4/13/20               77               95
# 12    4/20/20               85               92
# 13    4/27/20               61              108
# 14     5/4/20              101               94
# 15    5/11/20               81              116
# 16    5/18/20               85              104
# 17    5/25/20               93              107
# 18     6/1/20              105              109
# 19     6/8/20               99              104
# 20    6/15/20              101              109
# 21    6/22/20              120              120
# 22    6/29/20              103              111
# 23     7/6/20               90              110
# 24    7/13/20               94              105
# 25    7/20/20               98              118
# 26    7/27/20              108              113
# 27     8/3/20              109              133
# 28    8/10/20              112              103
# 29    8/17/20              124              107
# 30    8/24/20              119              114
# 31    8/31/20              111              116
# 32     9/7/20              112               91
# 33    9/14/20              108              112
# 34    9/21/20              117              110
# 35    9/28/20              121              122
# 36    10/5/20              100               89
# 37   10/12/20              141               94
# 38   10/19/20              105              115
# 39   10/26/20              138              122
# 40    11/2/20              104               89
# 41    11/9/20              110              103
# 42   11/16/20               98               94
# 43   11/23/20              112              106
# 44   11/30/20               86              106
# 45    12/7/20               78              114
# 46   12/14/20               72              126
# 47   12/21/20               82              103
# 48   12/28/20               63              105
# 49     1/4/21               54              105
# 50    1/11/21               82               84
# 51    1/18/21               73              101
# 52    1/25/21               19              107
# 53     2/1/21                0              102

# %%
#define dtype

# %%
# create a list to hold the modify formatted dates
formatted_dates = []

# index start at 1 therefore it must end at lenght + 1
for i in range(1, len(DUI_crashes_df["Date"]) + 1):
    try:
        # year has a format of 4 digits (upper case "Y")
        formatted_dates.append(pd.to_datetime(DUI_crashes_df["Date"][i], format ='%m/%d/%Y'))
    except ValueError: #if it fails year has a format of 2 digits [%y] (lower case "y")
        formatted_dates.append(pd.to_datetime(DUI_crashes_df["Date"][i], format ='%m/%d/%y'))
# avoid a SettingWithCopyWarning error in pandas
# src: https://www.youtube.com/watch?v=4R4WsDJ-KVc
DUI_crashes_df['Date'].loc[:] = formatted_dates
DUI_crashes_df
# Out:
#                    Date DUI crashes 2020 DUI crashes 2019
# 1   2020-02-03 00:00:00              102              114
# 2   2020-02-10 00:00:00              120               82
# 3   2020-02-17 00:00:00              100               88
# 4   2020-02-24 00:00:00               98              105
# 5   2020-03-02 00:00:00              110               98
# 6   2020-03-09 00:00:00              102              124
# 7   2020-03-16 00:00:00               58              101
# 8   2020-03-23 00:00:00               71               98
# 9   2020-03-30 00:00:00               64               96
# 10  2020-04-06 00:00:00               66               95
# 11  2020-04-13 00:00:00               77               95
# 12  2020-04-20 00:00:00               85               92
# 13  2020-04-27 00:00:00               61              108
# 14  2020-05-04 00:00:00              101               94
# 15  2020-05-11 00:00:00               81              116
# 16  2020-05-18 00:00:00               85              104
# 17  2020-05-25 00:00:00               93              107
# 18  2020-06-01 00:00:00              105              109
# 19  2020-06-08 00:00:00               99              104
# 20  2020-06-15 00:00:00              101              109
# 21  2020-06-22 00:00:00              120              120
# 22  2020-06-29 00:00:00              103              111
# 23  2020-07-06 00:00:00               90              110
# 24  2020-07-13 00:00:00               94              105
# 25  2020-07-20 00:00:00               98              118
# 26  2020-07-27 00:00:00              108              113
# 27  2020-08-03 00:00:00              109              133
# 28  2020-08-10 00:00:00              112              103
# 29  2020-08-17 00:00:00              124              107
# 30  2020-08-24 00:00:00              119              114
# 31  2020-08-31 00:00:00              111              116
# 32  2020-09-07 00:00:00              112               91
# 33  2020-09-14 00:00:00              108              112
# 34  2020-09-21 00:00:00              117              110
# 35  2020-09-28 00:00:00              121              122
# 36  2020-10-05 00:00:00              100               89
# 37  2020-10-12 00:00:00              141               94
# 38  2020-10-19 00:00:00              105              115
# 39  2020-10-26 00:00:00              138              122
# 40  2020-11-02 00:00:00              104               89
# 41  2020-11-09 00:00:00              110              103
# 42  2020-11-16 00:00:00               98               94
# 43  2020-11-23 00:00:00              112              106
# 44  2020-11-30 00:00:00               86              106
# 45  2020-12-07 00:00:00               78              114
# 46  2020-12-14 00:00:00               72              126
# 47  2020-12-21 00:00:00               82              103
# 48  2020-12-28 00:00:00               63              105
# 49  2021-01-04 00:00:00               54              105
# 50  2021-01-11 00:00:00               82               84
# 51  2021-01-18 00:00:00               73              101
# 52  2021-01-25 00:00:00               19              107
# 53  2021-02-01 00:00:00                0              102

# %%
DUI_crashes_df['Date'].value_counts()
# Out:
# 2020-03-09    1
# 2021-01-04    1
# 2020-06-01    1
# 2020-03-30    1
# 2020-07-06    1
# 2021-01-18    1
# 2020-10-12    1
# 2020-12-14    1
# 2020-12-07    1
# 2020-08-17    1
# 2020-03-23    1
# 2020-12-21    1
# 2020-04-06    1
# 2020-05-04    1
# 2020-06-29    1
# 2020-09-28    1
# 2020-02-17    1
# 2021-01-11    1
# 2020-10-19    1
# 2020-08-10    1
# 2020-02-03    1
# 2020-11-16    1
# 2020-06-22    1
# 2020-06-15    1
# 2020-03-02    1
# 2020-07-20    1
# 2020-05-25    1
# 2020-09-07    1
# 2020-05-11    1
# 2020-11-23    1
# 2020-08-03    1
# 2021-02-01    1
# 2020-08-31    1
# 2020-11-30    1
# 2020-07-13    1
# 2020-09-21    1
# 2020-04-20    1
# 2020-06-08    1
# 2020-11-02    1
# 2020-12-28    1
# 2020-02-10    1
# 2020-08-24    1
# 2020-10-26    1
# 2020-04-27    1
# 2020-02-24    1
# 2021-01-25    1
# 2020-03-16    1
# 2020-07-27    1
# 2020-11-09    1
# 2020-10-05    1
# 2020-09-14    1
# 2020-05-18    1
# 2020-04-13    1
# Name: Date, dtype: int64

# %%
#DUI_crashes_df["Date"].dtypes
#DUI_crashes_df['Date'].value_counts()
DUI_crashes_df['Date'] = pd.to_datetime(DUI_crashes_df.Date)
DUI_crashes_df.sort_values('Date')
# Out:
#          Date DUI crashes 2020 DUI crashes 2019
# 1  2020-02-03              102              114
# 2  2020-02-10              120               82
# 3  2020-02-17              100               88
# 4  2020-02-24               98              105
# 5  2020-03-02              110               98
# 6  2020-03-09              102              124
# 7  2020-03-16               58              101
# 8  2020-03-23               71               98
# 9  2020-03-30               64               96
# 10 2020-04-06               66               95
# 11 2020-04-13               77               95
# 12 2020-04-20               85               92
# 13 2020-04-27               61              108
# 14 2020-05-04              101               94
# 15 2020-05-11               81              116
# 16 2020-05-18               85              104
# 17 2020-05-25               93              107
# 18 2020-06-01              105              109
# 19 2020-06-08               99              104
# 20 2020-06-15              101              109
# 21 2020-06-22              120              120
# 22 2020-06-29              103              111
# 23 2020-07-06               90              110
# 24 2020-07-13               94              105
# 25 2020-07-20               98              118
# 26 2020-07-27              108              113
# 27 2020-08-03              109              133
# 28 2020-08-10              112              103
# 29 2020-08-17              124              107
# 30 2020-08-24              119              114
# 31 2020-08-31              111              116
# 32 2020-09-07              112               91
# 33 2020-09-14              108              112
# 34 2020-09-21              117              110
# 35 2020-09-28              121              122
# 36 2020-10-05              100               89
# 37 2020-10-12              141               94
# 38 2020-10-19              105              115
# 39 2020-10-26              138              122
# 40 2020-11-02              104               89
# 41 2020-11-09              110              103
# 42 2020-11-16               98               94
# 43 2020-11-23              112              106
# 44 2020-11-30               86              106
# 45 2020-12-07               78              114
# 46 2020-12-14               72              126
# 47 2020-12-21               82              103
# 48 2020-12-28               63              105
# 49 2021-01-04               54              105
# 50 2021-01-11               82               84
# 51 2021-01-18               73              101
# 52 2021-01-25               19              107
# 53 2021-02-01                0              102

# %%
#Chart 
#x_axis = np.arange(DUI_crashes_df['Date'][1], DUI_crashes_df['Date'][48], )
#plt.plot(formatted_dates, DUI_crashes_df['DUI crashes 2020'])
#plt.show()
#trying to remove the overlapping days
date_range = pd.date_range(formatted_dates[1],formatted_dates[48], freq='W')
date_range
# Out:
# DatetimeIndex(['2020-02-16', '2020-02-23', '2020-03-01', '2020-03-08',
#                '2020-03-15', '2020-03-22', '2020-03-29', '2020-04-05',
#                '2020-04-12', '2020-04-19', '2020-04-26', '2020-05-03',
#                '2020-05-10', '2020-05-17', '2020-05-24', '2020-05-31',
#                '2020-06-07', '2020-06-14', '2020-06-21', '2020-06-28',
#                '2020-07-05', '2020-07-12', '2020-07-19', '2020-07-26',
#                '2020-08-02', '2020-08-09', '2020-08-16', '2020-08-23',
#                '2020-08-30', '2020-09-06', '2020-09-13', '2020-09-20',
#                '2020-09-27', '2020-10-04', '2020-10-11', '2020-10-18',
#                '2020-10-25', '2020-11-01', '2020-11-08', '2020-11-15',
#                '2020-11-22', '2020-11-29', '2020-12-06', '2020-12-13',
#                '2020-12-20', '2020-12-27', '2021-01-03'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
print(len(date_range))
print(len(DUI_crashes_df['DUI crashes 2020']))
# Out:
# 47
# 53

# %%
D20 = DUI_crashes_df['DUI crashes 2020']

# %%
D19 = DUI_crashes_df['DUI crashes 2019']
D19.to_numpy()
# Out:
# array(['114', '82', '88', '105', '98', '124', '101', '98', '96', '95',
#        '95', '92', '108', '94', '116', '104', '107', '109', '104', '109',
#        '120', '111', '110', '105', '118', '113', '133', '103', '107',
#        '114', '116', '91', '112', '110', '122', '89', '94', '115', '122',
#        '89', '103', '94', '106', '106', '114', '126', '103', '105', '105',
#        '84', '101', '107', '102'], dtype=object)

# %%
D20.to_numpy()
# Out:
# array(['102', '120', '100', '98', '110', '102', '58', '71', '64', '66',
#        '77', '85', '61', '101', '81', '85', '93', '105', '99', '101',
#        '120', '103', '90', '94', '98', '108', '109', '112', '124', '119',
#        '111', '112', '108', '117', '121', '100', '141', '105', '138',
#        '104', '110', '98', '112', '86', '78', '72', '82', '63', '54',
#        '82', '73', '19', '0'], dtype=object)

# %%
#plt.bar(formatted_dates, D20)
#DUI2020, = plt.plot(formatted_dates, D20, color= "red")
#DUI2019, = plt.plot(formatted_dates, D19, color= "blue")

# %%
D = [102, 120, 100, 98, 110, 102, 58, 71, 64, 66,
       77, 85, 61, 101, 81, 85, 93, 105, 99, 101,
       120, 103, 90, 94, 98, 108, 109, 112, 124, 119,
       111, 112, 108, 117, 121, 100, 141, 105, 138,
       104, 110, 98, 112, 86, 78, 72, 82, 63, 54,
       82, 73, 19, 0]

# %%
D2 = [114, 82, 88, 105, 98, 124, 101, 98, 96, 95,
       95, 92, 108, 94, 116, 104, 107, 109, 104, 109,
       120, 111, 110, 105, 118, 113, 133, 103, 107,
       114, 116, 91, 112, 110, 122, 89, 94, 115, 122,
       89, 103, 94, 106, 106, 114, 126, 103, 105, 105,
       84, 101, 107, 102]

# %%
plt.ylim(0, 150)
plt.title("CA DUI crashes 2020 vs. 2019")
plt.xlabel("Dates")
plt.ylabel("Crashes")
plt.scatter(formatted_dates, D, marker="o", facecolors= "red", edgecolors= "black", label= "2020")
plt.scatter(formatted_dates, D2, marker= "x", color= "blue", label= "2019")
plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">
